# %%
print("Hello workd")
# Out:
# Hello workd

# %%
from src.api.v4.hmm_models import HMM
HMM()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 from src.api.v4.hmm_models import HMM
# ----> 2 HMM()
#
# TypeError: HMM.__init__() missing 2 required positional arguments: 'transition' and 'emission'
